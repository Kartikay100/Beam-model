# %%
from main import *
# Out:
# loadstep= 0
# iter= 0
# detS00= -8.604377895214597e-167
# detS01= -1.7811074894787706e-153
# detS10= 6.081581918871283e-153
# detS11= 7.00720924948109e-139
# detS00+S11+S10= -2.925705512794494e-124
# det 4800 x S11= -1.0027371518429563e-100
# detS00= -2.8985064818100144e-166
# detS01= -2.0491106109251236e-148
# detS10= 1.6384807875343365e-148
# detS11= 3.105018118357066e-132
# detS00+S11+S10= -2.056486212253277e-116
# det 4800 x S11= 7.107192450725341e-94
# detS00= -2.088038821160464e-164
# detS01= 3.591521958945468e-146
# detS10= -7.201706864121611e-147
# detS11= -2.5865620970362867e-126
# detS00+S11+S10= 6.453841952637406e-112
# det 4800 x S11= -8.613866861509785e-91
# detS00= 5.691867859929176e-168
# detS01= 2.141746092087219e-147
# detS10= 2.6687183895482454e-147
# detS11= 5.208104458726917e-126
# detS00+S11+S10= -2.779994614386214e-110
# det 4800 x S11= 2.4183925394696876e-88
# detS00= 2.9587652836413595e-177
# detS01= 1.7404603410448906e-151
# detS10= 1.0061620220575925e-152
# ...

# %%
from gen.gen_utilities import *
a = np.array([0,-0.01556701,0])
b = rotTensor(a)
c = np.array([0,0.01239586,0])
d = rotTensor(c)
e = d @ b
print(e)
rotVector(e)
# Out:
# [[ 0.99999497  0.         -0.00317114]
#  [ 0.          1.          0.        ]
#  [ 0.00317114  0.          0.99999497]]
# array([ 0.        , -0.00317115,  0.        ])

# %%
from gen.gen_utilities import *
aa = 4*np.pi/np.sqrt(2)
a = np.array([0,aa,0])
b = np.array([aa,0,0])
c = rotTensor(a) @ rotTensor(b)
d = rotTensor(b) @ rotTensor(a)

# %%
np.linalg.norm(rotVector(c))
# Out:
# np.float64(2.9996898102720166)

# %%
a1 = np.array([aa,aa,0])
np.linalg.norm(a1)
# Out:
# np.float64(12.566370614359172)

# %%
80E9*1.904761E-11*np.pi*20
# Out:
# 95.74373063110957

# %%
95.74373063110957 **2 *1 / (80E9*1.904761E-11)**2
# Out:
# 3947.841760435743

# %%
from gen.gen_gaussQuadCalc import *
gLQ(4)['weights']
# Out:
# array([0.34785485, 0.65214515, 0.65214515, 0.34785485])

# %%
from gen.gen_interpFunction import *
spectralNodes(5)
# Out:
# array([-1.00000000e+00, -6.54653671e-01,  1.61907524e-17,  6.54653671e-01,
#         1.00000000e+00])

# %%
from gen.gen_mesh1D import *
mesh1D(1,2,5)
# Out:
# (array([[0, 1, 2, 3, 4],
#         [4, 5, 6, 7, 8]], dtype=int32),
#  array([[0.   , 0.125, 0.25 , 0.375, 0.5  ],
#         [0.5  , 0.625, 0.75 , 0.875, 1.   ]]))

# %%
mesh1DLGL(1,2,4)
# Out:
# (array([[0, 1, 2, 3],
#         [3, 4, 5, 6]], dtype=int32),
#  array([[0.       , 0.1381966, 0.3618034, 0.5      ],
#         [0.5      , 0.6381966, 0.8618034, 1.       ]]))
