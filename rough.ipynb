# %%
from main import *
# Out:
# loadstep= 0
# iter= 0
# error= 0.004314193866949817 at loadstep= 1 iter= 1 at ratioLoadstep= 1.0
# solution [Tx]= -0.009287220228568418 [Ty]= 0.0 [Tz]= 1.0 [Rx]= 0.0 [Ry]= -0.011428578742852106 [Rz]= 0.0 [RxT]= 0.0 [RyT]= -0.011428578742852106 [RzT]= 0.0 at loadstep= 1 iter= 1 at ratioLoadstep= 1.0
# Length of beam is different before and after deformation. Current length is  1.0000474583672814
# iter= 1
# error= 1.17186711127273e-05 at loadstep= 1 iter= 2 at ratioLoadstep= 1.0
# solution [Tx]= -0.009286923151004533 [Ty]= 0.0 [Tz]= 0.9999526099789774 [Rx]= 0.0 [Ry]= -0.011428496647971239 [Rz]= 0.0 [RxT]= 0.0 [RyT]= -0.011428496647971239 [RzT]= 0.0 at loadstep= 1 iter= 2 at ratioLoadstep= 1.0
# Length of beam is close before and after deformation. Current length is  1.000000068027631
# iter= 2
# error= 1.1735537666579113e-07 at loadstep= 1 iter= 3 at ratioLoadstep= 1.0
# ...

# %%
import numpy as np
np.pi
# Out:
# 3.141592653589793

# %%
3.769453198*180/np.pi
# Out:
# 215.97375931749102

# %%
4.397679789876101*180/np.pi
# Out:
# 251.96849160987927

# %%
270*np.pi/180
# Out:
# 4.71238898038469

# %%
np.pi-1.8855073073342246
# Out:
# 1.2560853462555686

# %%
np.pi+1.2560853462555686
# Out:
# 4.397677999845362

# %%
if 1.8855073073342246+ 4.397677999845362 == 2*np.pi:
    print(True)
else:
    print(False)
# Out:
# True

# %%
from gen.gen_utilities import rotTensor, rotationTensor_Vec, skewSymmMat, rotVector
import numpy as np

# %%
a = np.array([0,3.141592653589793,0])
b = np.array([0,-2.4492935982947064e-16,0])
c = rotTensor(a) @ rotTensor(rotVector(rotTensor(a).T @ rotTensor(b)) * 0.5)

# %%
aa = rotVector(c.T @ rotTensor(a))
bb = rotVector(c.T @ rotTensor(b))
S0 = np.array([0.5,0.5])
dd = S0 @ np.array([aa,bb])
rotVector(c @ rotTensor(dd))
# Out:
# array([-0.        , -1.57079633, -0.        ])

# %%
c @ rotTensor(dd)
# Out:
# array([[-3.44509285e-16,  0.00000000e+00, -1.00000000e+00],
#        [ 0.00000000e+00,  1.00000000e+00,  0.00000000e+00],
#        [ 1.00000000e+00,  0.00000000e+00, -3.44509285e-16]])

# %%
from gen.gen_utilities import permutation_symbol
permutation_symbol()[:,1,:]
# Out:
# array([[ 0.,  0.,  1.],
#        [ 0.,  0.,  0.],
#        [-1.,  0.,  0.]])

# %%
4.7123889-np.pi
# Out:
# 1.5707962464102065

# %%
rotTensor

# %%
from itertools import product

for i, j in product(range(3), range(3)):
    print(i,j)
# Out:
# 0 0
# 0 1
# 0 2
# 1 0
# 1 1
# 1 2
# 2 0
# 2 1
# 2 2

# %%
q0 = 0
q = [1,2,3]
a = np.zeros((3,3))
a[:,:] =np.array([q0**2 + q[i]**2 - 0.5 if i==j else q[i]*q[j] for i, j in product(range(3), range(3))]).reshape(3,3)
a
# Out:
# array([[0.5, 2. , 3. ],
#        [2. , 3.5, 6. ],
#        [3. , 6. , 8.5]])

# %%
from itertools import permutations
for i, j, k in permutations(range(3),3):
    print(i, j, k)
# Out:
# 0 1 2
# 0 2 1
# 1 0 2
# 1 2 0
# 2 0 1
# 2 1 0
