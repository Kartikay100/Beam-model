# %%
import numpy as np
np.finfo(float).eps
# Out:
# np.float64(2.220446049250313e-16)

# %%
np.finfo(np.float64).eps
# Out:
# np.float64(2.220446049250313e-16)

# %%
np.finfo(np.float32).eps
# Out:
# np.float32(1.1920929e-07)

# %% [markdown]
# Float64 and float has same precision. Float 32 is less precise.
